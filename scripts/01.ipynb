# %% [markdown]
# # 我的第一个笔记本（Jupyter Notebook）
#
# **怎么用：** 点下面那个灰框里的代码 → 按 `Shift + Enter` → 结果就出来了。
#
# **和 01.py 的区别：**
# - `.ipynd` 笔记本：一段一段单独跑，适合边试边看结果
# - `.py` 脚本：整个文件一次跑完，适合写完整程序
#
# **两个必记住的规矩：**
# 1. 括号、引号必须用【英文】的：`( )` `" "` —— 中文的 `（）` `“”` 会让程序报错
# 2. 写代码前先把输入法切到英文（按 `Shift`）

# %%
print("我也会写程序啦！")
